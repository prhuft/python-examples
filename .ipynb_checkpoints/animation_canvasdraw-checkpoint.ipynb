# %%
""" Example: simple animation of sine wave with numpy. 
    Uses fig.canvas.draw() instead of matplotlib.animation
"""

# if you want the dynamic plot to work:
# %matplotlib notebook

## LIBRARIES
import numpy as np
import matplotlib.pyplot as plt
import math as m
import time

# %%
xpts = np.array(np.linspace(0,10,100))
ypts = np.sin(xpts)+2

# initialize the figure
fig = plt.figure()

# build an axes object that will show the plot in our figure
ax = fig.add_subplot(111)
ax.set_ylim(0,10)
ax.set_xlim(0,10)
ax.set_axis_off()
ax.set_aspect(aspect='equal')
ax.set_facecolor('black')

# add the axes object to the figure, and change the forecolor
fig.add_axes(ax)
fig.patch.set_facecolor('black')

# the initial plot line. note the comma after the variable name
line, = ax.plot(xpts,ypts,color='red',lw=3)

# Set "interactive mode" on (required for animation to work), and show the plot
#plt.ion()
plt.show()

# Run 100 frames of the animation
iters = 100
for i in range(0,iters):
    time.sleep(.05)

    # update the y-position
    ypts = np.sin(xpts+i)+5

    line.set_data(xpts,ypts)

    # update the plot
    fig.canvas.draw()
    fig.canvas.flush_events()
# Out:
# <img src="data:image/png;base64,..." width="640">
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-a441df3bee9f> in <module>()
#      37
#      38         # update the plot
# ---> 39         fig.canvas.draw()
#      40         fig.canvas.flush_events()
#      41     except KeyboardInterrupt:
#
# c:\program files (x86)\lib\site-packages\matplotlib\backends\backend_webagg_core.py in draw(self)
#     150             super().draw()
#     151         finally:
# --> 152             self.manager.refresh_all()  # Swap the frames.
#     153
#     154     def draw_idle(self):
#
# c:\program files (x86)\lib\site-packages\matplotlib\backends\backend_webagg_core.py in refresh_all(self)
#     442     def refresh_all(self):
#     443         if self.web_sockets:
# --> 444             diff = self.canvas.get_diff_image()
#     445             if diff is not None:
#     446                 for s in self.web_sockets:
#
# c:\program files (x86)\lib\site-packages\matplotlib\backends\backend_webagg_core.py in get_diff_image(self)
#     204             # Swap the renderer frames
#     205             self._renderer, self._last_renderer = (
# --> 206                 self._last_renderer, renderer)
#     207             self._force_full = False
#     208             self._png_is_old = False
#
# KeyboardInterrupt:
